# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e4b6529c-e9a9-4503-9b2d-33d7b96a58a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4b6529c-e9a9-4503-9b2d-33d7b96a58a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
df= pd.read_csv('gas_turbines.csv',error_bad_lines=False)
# Out:
# <ipython-input-31-3c75b31f7031>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df= pd.read_csv('gas_turbines.csv',error_bad_lines=False)

# %%
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
# !pip install keras
# !pip install tensorflow
# !pip install scikeras

# %%
from sklearn.preprocessing import StandardScaler
std_sca = StandardScaler()
standardized_df=std_sca.fit_transform(df)
df=pd.DataFrame(standardized_df, columns=df.columns)

# %%
df
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             TEY       CDP        CO       NOX
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.layers import Dense,Dropout
from keras.optimizers import RMSprop,Adam
from keras.models import Sequential
from tensorflow.keras.utils import plot_model
from scikeras.wrappers import KerasClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
features=df.drop(["TEY"],axis=1)
target=df[["TEY"]]

# %%
sclar = MinMaxScaler()
scale_data = sclar.fit_transform(features)
scale_data
# Out:
# array([[0.18418215, 0.45604964, 0.95131413, ..., 0.1353398 , 0.07152212,
#         0.59654817],
#        [0.18201978, 0.4663909 , 0.95588067, ..., 0.13398756, 0.07337235,
#         0.59713433],
#        [0.18529531, 0.47466391, 0.93900309, ..., 0.13456709, 0.07257648,
#         0.59379104],
#        ...,
#        [0.19596183, 0.4229576 , 0.98992213, ..., 0.11177221, 0.18055195,
#         0.68544912],
#        [0.18844295, 0.43329886, 0.98293633, ..., 0.12143106, 0.14169257,
#         0.71057802],
#        [0.18617304, 0.44157187, 0.96182146, ..., 0.1310899 , 0.11294597,
#         0.70266486]])

# %%
x_train,x_test, y_train, y_test = train_test_split(scale_data,target,test_size=0.30,random_state=12)

# %%
x_train.shape,y_train.shape
# Out:
# ((10527, 10), (10527, 1))

# %%
x_test.shape,y_test.shape
# Out:
# ((4512, 10), (4512, 1))

# %%
epochs=40
batch_size=100

# %%
model= Sequential()
model.add(Dense(16,activation='relu',input_shape=(10,)))
model.add(Dense(12,activation='relu'))
model.add(Dense(1,activation='linear'))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_36 (Dense)            (None, 16)                176
#
#  dense_37 (Dense)            (None, 12)                204
#
#  dense_38 (Dense)            (None, 1)                 13
#
# ...
# Total params: 393 (1.54 KB)
# Trainable params: 393 (1.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
plot_model(model,to_file='model.png',show_shapes=True)

# %%
model.compile(optimizer='adam',loss='mse',metrics='mse')

# %%
history=model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,verbose=2,validation_data=(x_test,y_test))
# Out:
# Epoch 1/40
# 106/106 - 1s - loss: 18079.3945 - mse: 18079.3945 - val_loss: 17504.4531 - val_mse: 17504.4512 - 1s/epoch - 13ms/step
# Epoch 2/40
# 106/106 - 0s - loss: 15173.7607 - mse: 15173.7607 - val_loss: 11488.3174 - val_mse: 11488.3174 - 250ms/epoch - 2ms/step
# Epoch 3/40
# 106/106 - 0s - loss: 6765.5151 - mse: 6765.5151 - val_loss: 2350.1753 - val_mse: 2350.1753 - 253ms/epoch - 2ms/step
# Epoch 4/40
# 106/106 - 0s - loss: 696.8919 - mse: 696.8920 - val_loss: 66.4969 - val_mse: 66.4969 - 244ms/epoch - 2ms/step
# Epoch 5/40
# 106/106 - 0s - loss: 48.1230 - mse: 48.1230 - val_loss: 44.2959 - val_mse: 44.2959 - 253ms/epoch - 2ms/step
# Epoch 6/40
# 106/106 - 0s - loss: 43.2180 - mse: 43.2180 - val_loss: 42.2754 - val_mse: 42.2754 - 266ms/epoch - 3ms/step
# Epoch 7/40
# 106/106 - 0s - loss: 41.2170 - mse: 41.2170 - val_loss: 40.2931 - val_mse: 40.2931 - 262ms/epoch - 2ms/step
# Epoch 8/40
# ...

# %%
y_pred= model.predict(x_test)
y_pred
# Out:
# 141/141 [==============================] - 0s 2ms/step
# array([[112.85197 ],
#        [124.347984],
#        [130.08347 ],
#        ...,
#        [117.08181 ],
#        [156.90709 ],
#        [129.48764 ]], dtype=float32)

# %%
y_test
# Out:
#           TEY
# 4841   112.06
# 6730   127.18
# 7694   132.70
# 9566   159.95
# 6017   132.85
# ...       ...
# 8007   133.56
# 5394   133.73
# 14601  112.90
# 917    159.87
# 6196   119.74
#
# [4512 rows x 1 columns]

# %%
y_test_new=np.array(y_test)
y_test_new
# Out:
# array([[112.06],
#        [127.18],
#        [132.7 ],
#        ...,
#        [112.9 ],
#        [159.87],
#        [119.74]])
